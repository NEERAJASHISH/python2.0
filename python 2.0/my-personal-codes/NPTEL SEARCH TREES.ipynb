# %%
class tres():
    def __init__(self,name,age,gender,marks):
        self.name = name
        self.gender  = gender
        self.age = age
        self.marks = marks
    def compute(self):
        print(f'The name is {self.name} age is {self.age} and gender is {self.gender}')
    def avg(self,m1,m2):
        average = (m1+m2)/2
        print(f'The average marks is {average}')
        
        
        
        
        
k = input("enter the user name:\n")  
l = input("Enter the gender:\n")
i = int(input("Enter the age:\n"))
o = int(input("Entert the marks:\n"))
mark1 = int(input("Enter the mark1:\n"))
mark2 = int(input("Enter the mark2:\n"))

obj1 = tres(k,i,l,o)
obj1.compute()
obj1.avg(mark1,mark2)
# Out:
# enter the user name:
# neeraj
# Enter the gender:
# male
# Enter the age:
# 21
# Entert the marks:
# 900
# Enter the mark1:
# 800
# Enter the mark2:
# 700
# The name is neeraj age is 21 and gender is male
# The average marks is 750.0

# %%
class trees():
    def __init__(self,initval = None):
        self.value = initval
        if self.value:
            self.left = trees()
            self.right = trees()
        else:
            self.left = None  ##
            self.right = None
    def isempty(self):
        return(self.value == None)
    
    def inorder(self):
        if self.isempty():
            return([])
        else:
            return(self.left.inorder() +
                  [self.value] + self.right.inorder())
        
    def __str__(self):
        return(str(self.inorder()))
    
    def find(self,v):
        if self.isempty():
            return(False)
        if self.value == v:
            return(True)
        if v < self.value:
            return(self.left.find(v))
        else:
            v > self.value
            return(self.right.find(v))
        
    def minval(self):
        if self.left == None:
            return(self.value)
        else:
            (self.left.minval())
    def maxval(self):
        if self.right == None:
            retur(self.value)
        else:
            return(self.right.maxval())
        
    def insert(self,v):
        if self.isempty():
            self.value == v:
                self.left = trees()
                self.right = trees()
        if self.value == v:
            return
        if v < self.value:
            self.left.insert(v)
            return
        if v > self.value:
            self.right.insert(v)
            return
