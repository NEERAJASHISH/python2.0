# %%
import pandas as pd
grades = pd.read_csv("grades (1).csv")
grades
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 22       Bill        8.00    NaN
# 23        Ted         NaN    NaN

# %%
pd.options.display.max_rows
# maximium and minumum rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %%
pd.options.display.min_rows = 10
grades
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 22       Bill        8.00    NaN
# 23        Ted         NaN    NaN

# %%
pd.options.display.max_rows = 24 # setting the max limit id there is more data
grades
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 22       Bill        8.00    NaN
# 23        Ted         NaN    NaN

# %%
grades.head() # by deaful it will print first five rows
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0

# %%
grades.head(21)
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0

# %%
grades.tail() #by default print the last five rows
# Out:
#       Name  StudyHours  Grade
# 19    Skye        12.0   52.0
# 20  Daniel        12.5   63.0
# 21   Aisha        12.0   64.0
# 22    Bill         8.0    NaN
# 23     Ted         NaN    NaN

# %%
grades.tail(10)
# Out:
#       Name  StudyHours  Grade
# 14   Jenny        15.5   70.0
# 15  Jakeem         8.0   27.0
# 16  Helena         9.0   36.0
# 17   Ismat         6.0   35.0
# 18   Anila        10.0   48.0
# 19    Skye        12.0   52.0
# 20  Daniel        12.5   63.0
# 21   Aisha        12.0   64.0
# 22    Bill         8.0    NaN
# 23     Ted         NaN    NaN

# %%
# !jt -r
# Out:
# Reset css and font defaults in:
# C:\Users\USER\.jupyter\custom &
# C:\Users\USER\AppData\Roaming\jupyter\nbextensions

# %%
grades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        24 non-null     object
#  1   StudyHours  23 non-null     float64
#  2   Grade       22 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 704.0+ bytes

# %%
grades.describe()
# Out:
#        StudyHours      Grade
# count   23.000000  22.000000
# mean    10.413043  49.181818
# std      3.447338  21.737912
# min      1.000000   3.000000
# 25%      8.750000  36.250000
# 50%     10.000000  49.500000
# 75%     12.250000  62.750000
# max     16.000000  97.000000

# %%
grades.describe(include = "O" ) # these represents the most unique value
# Out:
#        Name
# count    24
# unique   24
# top     Dan
# freq      1

# %%
type(grades)
# Out:
# pandas.core.frame.DataFrame

# %%
len(grades)
# Out:
# 24

# %%
grades
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 22       Bill        8.00    NaN
# 23        Ted         NaN    NaN

# %%
round(grades,0) # rounding off to zero
# Out:
#          Name  StudyHours  Grade
# 0         Dan        10.0   50.0
# 1       Joann        12.0   50.0
# 2       Pedro         9.0   47.0
# 3       Rosie        16.0   97.0
# 4       Ethan         9.0   49.0
# 5       Vicky         1.0    3.0
# 6    Frederic        12.0   53.0
# 7      Jimmie         9.0   42.0
# 8      Rhonda         8.0   26.0
# 9    Giovanni        14.0   74.0
# 10  Francesca        16.0   82.0
# 11      Rajab        14.0   62.0
# 12    Naiyana         9.0   37.0
# 13       Kian         8.0   15.0
# 14      Jenny        16.0   70.0
# 15     Jakeem         8.0   27.0
# 16     Helena         9.0   36.0
# 17      Ismat         6.0   35.0
# 18      Anila        10.0   48.0
# 19       Skye        12.0   52.0
# 20     Daniel        12.0   63.0
# 21      Aisha        12.0   64.0
# 22       Bill         8.0    NaN
# 23        Ted         NaN    NaN

# %%
min(grades) # its works according to the alphabetical order because in the first row has the grades where g is first in aplha order
# Out:
# 'Grade'

# %% [markdown]
# # Data frame attributes(charecteristic)

# %%
grades
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 22       Bill        8.00    NaN
# 23        Ted         NaN    NaN

# %%
grades.shape  # it  has 24 rows and three  coloumns
# Out:
# (24, 3)

# %%
grades.size #the grade size is given by number of rows and coloums
# Out:
# 72

# %%
24*3
# Out:
# 72

# %%
grades.index
# Out:
# RangeIndex(start=0, stop=24, step=1)

# %%
grades.columns
# Out:
# Index(['Name', 'StudyHours', 'Grade'], dtype='object')

# %% [markdown]
# # Dataframe methods

# %%
#the methods are same as the oob
# for example obj1.method()

# %%
grades.head()
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0

# %%
grades.head(10)
# Out:
#        Name  StudyHours  Grade
# 0       Dan       10.00   50.0
# 1     Joann       11.50   50.0
# 2     Pedro        9.00   47.0
# 3     Rosie       16.00   97.0
# 4     Ethan        9.25   49.0
# 5     Vicky        1.00    3.0
# 6  Frederic       11.50   53.0
# 7    Jimmie        9.00   42.0
# 8    Rhonda        8.50   26.0
# 9  Giovanni       14.50   74.0

# %%
grades.tail()
# Out:
#       Name  StudyHours  Grade
# 19    Skye        12.0   52.0
# 20  Daniel        12.5   63.0
# 21   Aisha        12.0   64.0
# 22    Bill         8.0    NaN
# 23     Ted         NaN    NaN

# %%
grades.tail(3)
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   64.0
# 22   Bill         8.0    NaN
# 23    Ted         NaN    NaN

# %%
grades.min() # it returns the min value in each coloum
# Out:
# Name          Aisha
# StudyHours      1.0
# Grade           3.0
# dtype: object

# %%
grades.max() # it returns the max value in each coloum
# Out:
# Name          Vicky
# StudyHours     16.0
# Grade          97.0
# dtype: object

# %%
grades.describe()
# Out:
#        StudyHours      Grade
# count   23.000000  22.000000
# mean    10.413043  49.181818
# std      3.447338  21.737912
# min      1.000000   3.000000
# 25%      8.750000  36.250000
# 50%     10.000000  49.500000
# 75%     12.250000  62.750000
# max     16.000000  97.000000

# %% [markdown]
# # method chaining

# %%
grades.mean()
# Out:
# <ipython-input-33-42c16db8a814>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   grades.mean()
# StudyHours    10.413043
# Grade         49.181818
# dtype: float64

# %%
grades.mean().sort_values() # here we are sorting the ,mean values
# Out:
# <ipython-input-34-002cc0bd1528>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   grades.mean().sort_values() # here we are sorting the ,mean values
# StudyHours    10.413043
# Grade         49.181818
# dtype: float64

# %%
grades.std().sort_values()
# Out:
# <ipython-input-35-a5dcffd91e08>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   grades.std().sort_values()
# StudyHours     3.447338
# Grade         21.737912
# dtype: float64

# %%
grades.count().sort_values().head(2)
# Out:
# Grade         22
# StudyHours    23
# dtype: int64

# %%
grades
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 22       Bill        8.00    NaN
# 23        Ted         NaN    NaN

# %%
grades.sort_values(by = "StudyHours")
# Out:
#          Name  StudyHours  Grade
# 5       Vicky        1.00    3.0
# 17      Ismat        6.00   35.0
# 22       Bill        8.00    NaN
# 15     Jakeem        8.00   27.0
# 13       Kian        8.00   15.0
# 8      Rhonda        8.50   26.0
# 2       Pedro        9.00   47.0
# 16     Helena        9.00   36.0
# 7      Jimmie        9.00   42.0
# 12    Naiyana        9.00   37.0
# 4       Ethan        9.25   49.0
# 18      Anila       10.00   48.0
# 0         Dan       10.00   50.0
# 6    Frederic       11.50   53.0
# 1       Joann       11.50   50.0
# 19       Skye       12.00   52.0
# 21      Aisha       12.00   64.0
# 20     Daniel       12.50   63.0
# 11      Rajab       13.75   62.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 14      Jenny       15.50   70.0
# 3       Rosie       16.00   97.0
# 23        Ted         NaN    NaN

# %%
grades.sort_index(axis = 0)
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 22       Bill        8.00    NaN
# 23        Ted         NaN    NaN

# %%
grades.sort_index(axis = 1) # on the alphabetical order change in the oth row
# Out:
#     Grade       Name  StudyHours
# 0    50.0        Dan       10.00
# 1    50.0      Joann       11.50
# 2    47.0      Pedro        9.00
# 3    97.0      Rosie       16.00
# 4    49.0      Ethan        9.25
# 5     3.0      Vicky        1.00
# 6    53.0   Frederic       11.50
# 7    42.0     Jimmie        9.00
# 8    26.0     Rhonda        8.50
# 9    74.0   Giovanni       14.50
# 10   82.0  Francesca       15.50
# 11   62.0      Rajab       13.75
# 12   37.0    Naiyana        9.00
# 13   15.0       Kian        8.00
# 14   70.0      Jenny       15.50
# 15   27.0     Jakeem        8.00
# 16   36.0     Helena        9.00
# 17   35.0      Ismat        6.00
# 18   48.0      Anila       10.00
# 19   52.0       Skye       12.00
# 20   63.0     Daniel       12.50
# 21   64.0      Aisha       12.00
# 22    NaN       Bill        8.00
# 23    NaN        Ted         NaN

# %%
grades.sort_values(by = "Grade", ascending = True) # samll to high
# Out:
#          Name  StudyHours  Grade
# 5       Vicky        1.00    3.0
# 13       Kian        8.00   15.0
# 8      Rhonda        8.50   26.0
# 15     Jakeem        8.00   27.0
# 17      Ismat        6.00   35.0
# 16     Helena        9.00   36.0
# 12    Naiyana        9.00   37.0
# 7      Jimmie        9.00   42.0
# 2       Pedro        9.00   47.0
# 18      Anila       10.00   48.0
# 4       Ethan        9.25   49.0
# 1       Joann       11.50   50.0
# 0         Dan       10.00   50.0
# 19       Skye       12.00   52.0
# 6    Frederic       11.50   53.0
# 11      Rajab       13.75   62.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 14      Jenny       15.50   70.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 3       Rosie       16.00   97.0
# 22       Bill        8.00    NaN
# 23        Ted         NaN    NaN

# %%
grades.sort_values(by = "Grade",ascending = False) high to small
# Out:
#   File "<ipython-input-42-d22bdfe680de>", line 1
#     grades.sort_values(by = "Grade",ascending = False) high to small
#                                                        ^
# SyntaxError: invalid syntax

# %%
grades.sort_values("StudyHours" ,inplace = False)
grades

# %%
grades["Name"]

# %% [markdown]
# # Extracting the coloumns

# %%
grades["StudyHours"]

# %%
grades[["StudyHours","Grade"]]

# %% [markdown]
# # Extracting the coloums with dot notation

# %%
grades.Name

# %%
grades.Name.equals(grades["Name"])

# %%
summer[0:1] # extracting the first row

# %%
summer.iloc[0]

# %%
type(summer.iloc[0]) # it is a data series

# %%
type(summer[0:1] )# it is a data frame

# %%
summer.iloc[-1]

# %%
summer.iloc[[1,2,3]]

# %%
summer[1:4] # slicing the string

# %%
summer.iloc[1:5]  # methods

# %%
grades

# %%
grades[:-2]

# %%
grades[-6:]

# %%
import pandas as pd
cars  = pd.read_csv("cars.csv")
cars

# %%
pd.options.display.max_rows = 399
cars

# %%
cars.iloc[-5:]

# %%
cars.iloc[0,3]

# %%
cars.iloc[393,5]

# %%
cars.iloc[0, :3]

# %%
cars.iloc[0,[0,1,2,3,4]]

# %%
cars.iloc[0,[4,5,6,7,8]]

# %%
cars.iloc[0:5,[0,1,2,3,4,5,6,7,8]]

# %%
cars.iloc[:, :8]

# %%
cars.iloc[1 ,[0,1,2,3]]

# %%
cars.iloc[-2:]

# %%
cars.iloc[-100:]

# %% [markdown]
#   # day 2

# %%
import pandas as pd

# %%
lister = ["new york","new jersy","philedepphia"]
pd.Series(lister)

# %%
lottery = [1,2,3,4,5,6,7]
pd.Series(lottery)

# %%
dic = {"usa": "newyork","india":"delhi","england":"london"}
pd.Series(dic)

# %%
grades

# %%
grades.values

# %% [markdown]
# # attributes

# %%
grades.index

# %%
grades.dtypes

# %% [markdown]
#  # methods ()

# %%
grades.sum()

# %%
grades.product()

# %%
grades.mean()

# %%
grades.describe()

# %% [markdown]
# # parameters and arguments

# %%
fruits = ["bannana","pineapple","grapes","dragonfruit","coconut","apples","mangoes"]
weekdays = ["monday","tuesday","wednesday","thursday","friday","saturday","sunday"]
pd.Series(data = weekdays,index = fruits)
# other ways 
pd.Series(fruits,weekdays)

# %%
cars

# %%
cars  = pd.read_csv("cars.csv",usecols=["cylinders"],squeeze= True) # True will give series
cars

# %%
len(cars)

# %%
type(cars)

# %%
dict(cars)

# %%
cars =pd.read_csv('cars.csv')
cars

# %%
dict(cars) # the keys are mpg cylinder displacement horesepower

# %%
max(cars)

# %%
cars.max(axis=1)

# %%
cars.min()

# %%
cars.min(axis=1)

# %%
cars.values

# %%
import pandas as pd
cars =pd.read_csv("cars.csv")
cars

# %%
pd.options.display.max_rows = 399

# %%
cars

# %%
cars.ndim

# %%
cars.sort_values(by = "horsepower" ,ascending=False)

# %%
cars = pd.read_csv("cars.csv",usecols=["horsepower"],squeeze=True)
cars.sort_values().head()

# %%
import pandas as pd
cars = pd.read_csv("cars.csv")
cars

# %%
cars.sort_values(by = "horsepower",ascending=False,inplace = True)
cars

# %%
cars # the data is changed due to inplace operators the index is also suffeled

# %%
cars.sort_index()

# %%
cars.iloc[0,[0,1,2,3]]

# %%
cars[0:4]

# %%
cars.iloc[0,[0]]

# %%
import pandas as pd
cars = pd.read_csv("cars.csv")
cars

# %%
cars.sort_index()

# %%
cars.sort_index(ascending=False,inplace = True)
cars

# %%
cars # The cars the data changed

# %%
# the the cars data can be changed to back

# %%
cars.sort_index() # the data changed back to normal form

# %%
cars = pd.read_csv("cars.csv",usecols=["horsepower"]  ,squeeze= True)
cars

# %%
cars[1]

# %%
cars = pd.read_csv("cars.csv", index_col= "displacement") 
# changiing the coloumn of thr index

# %%
cars # the displacement has been changed to index coloumn

# %%
cars  = pd.read_csv("cars.csv", index_col= "displacement", squeeze=True ) 
cars

# %%
cars =  pd.read_csv("cars.csv",usecols = ["cylinders"], squeeze=True ) 
cars

# %%
cars[0]

# %%
cars[[393,394]]

# %%
grades.info()

# %%
x = grades.iloc[:,1:3].values # [rows,columns]
x
# Out:
# array([[10.  , 50.  ],
#        [11.5 , 50.  ],
#        [ 9.  , 47.  ],
#        [16.  , 97.  ],
#        [ 9.25, 49.  ],
#        [ 1.  ,  3.  ],
#        [11.5 , 53.  ],
#        [ 9.  , 42.  ],
#        [ 8.5 , 26.  ],
#        [14.5 , 74.  ],
#        [15.5 , 82.  ],
#        [13.75, 62.  ],
#        [ 9.  , 37.  ],
#        [ 8.  , 15.  ],
#        [15.5 , 70.  ],
#        [ 8.  , 27.  ],
#        [ 9.  , 36.  ],
#        [ 6.  , 35.  ],
#        [10.  , 48.  ],
#        [12.  , 52.  ],
#        [12.5 , 63.  ],
#        [12.  , 64.  ],
#        [ 8.  ,   nan],
#        [  nan,   nan]])

# %%
y = grades.iloc[:,1].values # [rows,columns]
y
# Out:
# array([10.  , 11.5 ,  9.  , 16.  ,  9.25,  1.  , 11.5 ,  9.  ,  8.5 ,
#        14.5 , 15.5 , 13.75,  9.  ,  8.  , 15.5 ,  8.  ,  9.  ,  6.  ,
#        10.  , 12.  , 12.5 , 12.  ,  8.  ,   nan])
